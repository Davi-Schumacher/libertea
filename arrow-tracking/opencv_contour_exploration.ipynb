# %%
import cv2

# %%
from PIL import Image

# %%
import numpy as np

# %%
from pathlib import Path

# %%
img = Image.open('./examples/20201026234212_1.jpg')
im.show('image',img)

# %%
img_array = np.array(img)

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1080 at 0x28580775460>

# %%
gray = cv2.cvtColor(img_array,cv2.COLOR_BGR2GRAY)
#apply canny edge detection to the image
edges = cv2.Canny(gray,50,150,apertureSize = )

# %%
edges = cv2.Canny(gray,300,500,apertureSize = 3)
edge_img = Image.fromarray(edges)
edge_img
# Out:
# <PIL.Image.Image image mode=L size=1920x1080 at 0x28582428FA0>

# %%
def get_contour(img: np.array):
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    edges = cv2.Canny(gray,300,500,apertureSize=3)
    return Image.fromarray(edges)

# %%
for f in Path('./examples').glob('*.jpg'):
    img = Image.open(f)
    img_array = np.array(img)
    edges = get_contour(img_array)
    img.show()
    edges.show()
